# %% [markdown]
# # Likes Report

# %% [markdown]
# ## Section 1 - Questions about data

# %% [markdown]
# ### James Pauline, 9/10/2025

# %% [markdown]
# #### I am the source of the analyzed instagram data, as the likes being analyzed are my own

# %% [markdown]
# #### This data was created to track what posts ive liked and it serves the purpose of guaging what content I am interested in

# %% [markdown]
# #### This data would be reliable because it was generated by the Meta company

# %% [markdown]
# #### This data could also be somewhat unreliable due to my inconsistent use of the instagram platform

# %% [markdown]
# ## Section 2 - Open and load the json file

# %%
# import statements
import json 
import pandas as pd
import matplotlib as plt

# %%
path = r"C:\Users\jttor\Downloads\instagram-jam.t.p-2025-08-25-eDfHKeoA\your_instagram_activity\likes\liked_posts.json"
with open (path) as l:
    dict = json.load(l)

# %% [markdown]
# ## Section 3 - Convert the data into DataFrame object and assign it to a variable using pandas

# %%
df = pd.DataFrame(dict)
df.head()
# Out:
#                                    likes_media_likes
# 0  {'title': 'marcuspork', 'string_list_data': [{...
# 1  {'title': 'yung_dawnn', 'string_list_data': [{...
# 2  {'title': 'jocelynmarcucci', 'string_list_data...
# 3  {'title': 'misspaige.elizabeth', 'string_list_...
# 4  {'title': 'paigethrowsclay', 'string_list_data...

# %%
# find keys
dict.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %%
df_tidy = pd.DataFrame(dict['likes_media_likes'])
df_tidy.head()
# Out:
#                  title                                   string_list_data
# 0           marcuspork  [{'href': 'https://www.instagram.com/reel/DMQf...
# 1           yung_dawnn  [{'href': 'https://www.instagram.com/reel/DKiB...
# 2      jocelynmarcucci  [{'href': 'https://www.instagram.com/p/DLwFT9M...
# 3  misspaige.elizabeth  [{'href': 'https://www.instagram.com/p/DLgLVm7...
# 4      paigethrowsclay  [{'href': 'https://www.instagram.com/p/DLnxfDa...

# %% [markdown]
# ## Section 4 - create a timestamp column

# %%
df_tidy['string_list_data'].iloc[0]
# Out:
# [{'href': 'https://www.instagram.com/reel/DMQfOc-pcnQ/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1752938141}]

# %%
type(df_tidy['string_list_data'].iloc[0])
# Out:
# list

# %%
len(df_tidy['string_list_data'].iloc[0])
# Out:
# 1

# %%
df_tidy['string_list_data'].iloc[0][0]
# Out:
# {'href': 'https://www.instagram.com/reel/DMQfOc-pcnQ/',
#  'value': 'ð\x9f\x91\x8d',
#  'timestamp': 1752938141}

# %%
df_tidy['string_list_data'].iloc[0][0]['timestamp']
# Out:
# 1752938141

# %%
df_tidy['Time of Like'] = [i[0]['timestamp'] for i in df_tidy['string_list_data']]

df_tidy.head()
# Out:
#                  title                                   string_list_data  \
# 0           marcuspork  [{'href': 'https://www.instagram.com/reel/DMQf...
# 1           yung_dawnn  [{'href': 'https://www.instagram.com/reel/DKiB...
# 2      jocelynmarcucci  [{'href': 'https://www.instagram.com/p/DLwFT9M...
# 3  misspaige.elizabeth  [{'href': 'https://www.instagram.com/p/DLgLVm7...
# 4      paigethrowsclay  [{'href': 'https://www.instagram.com/p/DLnxfDa...
#
#    Time of Like
# 0    1752938141
# 1    1752335042
# 2    1751780620
# 3    1751780378
# 4    1751778378

# %%
# good to have
from datetime import datetime
df_tidy['Date of Like'] = [datetime.fromtimestamp(i[0]['timestamp']) for i in df_tidy['string_list_data']]

# %%
df_tidy.head()
# Out:
#                  title                                   string_list_data  \
# 0           marcuspork  [{'href': 'https://www.instagram.com/reel/DMQf...
# 1           yung_dawnn  [{'href': 'https://www.instagram.com/reel/DKiB...
# 2      jocelynmarcucci  [{'href': 'https://www.instagram.com/p/DLwFT9M...
# 3  misspaige.elizabeth  [{'href': 'https://www.instagram.com/p/DLgLVm7...
# 4      paigethrowsclay  [{'href': 'https://www.instagram.com/p/DLnxfDa...
#
#    Time of Like        Date of Like
# 0    1752938141 2025-07-19 11:15:41
# 1    1752335042 2025-07-12 11:44:02
# 2    1751780620 2025-07-06 01:43:40
# 3    1751780378 2025-07-06 01:39:38
# 4    1751778378 2025-07-06 01:06:18

# %%
df_tidy['href'] = [i[0]['href'] for i in df_tidy['string_list_data']]
df_tidy.head()
# Out:
#                  title                                   string_list_data  \
# 0           marcuspork  [{'href': 'https://www.instagram.com/reel/DMQf...
# 1           yung_dawnn  [{'href': 'https://www.instagram.com/reel/DKiB...
# 2      jocelynmarcucci  [{'href': 'https://www.instagram.com/p/DLwFT9M...
# 3  misspaige.elizabeth  [{'href': 'https://www.instagram.com/p/DLgLVm7...
# 4      paigethrowsclay  [{'href': 'https://www.instagram.com/p/DLnxfDa...
#
#    Time of Like        Date of Like  \
# 0    1752938141 2025-07-19 11:15:41
# 1    1752335042 2025-07-12 11:44:02
# 2    1751780620 2025-07-06 01:43:40
# 3    1751780378 2025-07-06 01:39:38
# 4    1751778378 2025-07-06 01:06:18
#
#                                           href
# 0  https://www.instagram.com/reel/DMQfOc-pcnQ/
# 1  https://www.instagram.com/reel/DKiBTJVu8d2/
# 2     https://www.instagram.com/p/DLwFT9MMYkc/
# 3     https://www.instagram.com/p/DLgLVm7OPrf/
# 4     https://www.instagram.com/p/DLnxfDaAsIY/

# %%
df_tidy['value'] = [i[0]['value'] for i in df_tidy['string_list_data']]
df_tidy.head()
# Out:
#                  title                                   string_list_data  \
# 0           marcuspork  [{'href': 'https://www.instagram.com/reel/DMQf...
# 1           yung_dawnn  [{'href': 'https://www.instagram.com/reel/DKiB...
# 2      jocelynmarcucci  [{'href': 'https://www.instagram.com/p/DLwFT9M...
# 3  misspaige.elizabeth  [{'href': 'https://www.instagram.com/p/DLgLVm7...
# 4      paigethrowsclay  [{'href': 'https://www.instagram.com/p/DLnxfDa...
#
#    Time of Like        Date of Like  \
# 0    1752938141 2025-07-19 11:15:41
# 1    1752335042 2025-07-12 11:44:02
# 2    1751780620 2025-07-06 01:43:40
# 3    1751780378 2025-07-06 01:39:38
# 4    1751778378 2025-07-06 01:06:18
#
#                                           href value
# 0  https://www.instagram.com/reel/DMQfOc-pcnQ/  ð
# 1  https://www.instagram.com/reel/DKiBTJVu8d2/  ð
# 2     https://www.instagram.com/p/DLwFT9MMYkc/  ð
# 3     https://www.instagram.com/p/DLgLVm7OPrf/  ð
# ...

# %%
df_tidy.drop(columns = ['string_list_data'])
# Out:
#                    title  Time of Like        Date of Like  \
# 0             marcuspork    1752938141 2025-07-19 11:15:41
# 1             yung_dawnn    1752335042 2025-07-12 11:44:02
# 2        jocelynmarcucci    1751780620 2025-07-06 01:43:40
# 3    misspaige.elizabeth    1751780378 2025-07-06 01:39:38
# 4        paigethrowsclay    1751778378 2025-07-06 01:06:18
# ..                   ...           ...                 ...
# 144              j7krazy    1726193645 2024-09-12 22:14:05
# 145   rosieinthesunshine    1726005132 2024-09-10 17:52:12
# 146   rosieinthesunshine    1726003562 2024-09-10 17:26:02
# 147           shake_1121    1725697211 2024-09-07 04:20:11
# 148   rosieinthesunshine    1725050577 2024-08-30 16:42:57
#
#                                             href value
# 0    https://www.instagram.com/reel/DMQfOc-pcnQ/  ð
# 1    https://www.instagram.com/reel/DKiBTJVu8d2/  ð
# 2       https://www.instagram.com/p/DLwFT9MMYkc/  ð
# ...

# %% [markdown]
# ## Section 5 - use groupby() and count() mathods

# %%
df_tidy.groupby('title').count().sort_values('Time of Like', ascending = False)
# Out:
#                      string_list_data  Time of Like  Date of Like  href  value
# title
# rosieinthesunshine                 18            18            18    18     18
# igndotcom                           4             4             4     4      4
# epaul5305                           3             3             3     3      3
# bipolarerpolarfisch                 2             2             2     2      2
# tabbycatmittens                     2             2             2     2      2
# ...                               ...           ...           ...   ...    ...
# doggvids                            1             1             1     1      1
# diorgasms                           1             1             1     1      1
# digital.chomeur                     1             1             1     1      1
# dexerto                             1             1             1     1      1
# zaddysscarystories                  1             1             1     1      1
#
# ...

# %% [markdown]
# ## Section 6 - Create a hypothesis that could be proved or disproved using another personal json file

# %% [markdown]
# I have followed more friend related accounts than other accounts recently (Content creators, companies, meme pages, etc)

# %% [markdown]
# ## Section 7 - Chose json file I think may be applicable

# %% [markdown]
# I have selected the file named following.json. Ideally this file will give me a good idea about how many real-life friends I follow on instagram by analyzing the first several entries

# %% [markdown]
# ## Section 8 - Open and load following.json

# %%
path = r"C:\Users\jttor\Downloads\instagram-jam.t.p-2025-08-25-eDfHKeoA\connections\followers_and_following\following.json"
with open (path) as follow:
    dict = json.load(follow)

# %% [markdown]
# ## Section 9 - Convert the data to as tidy of a form as possible

# %%
df = pd.DataFrame(dict)
df.head
# Out:
# <bound method NDFrame.head of                               relationships_following
# 0   {'title': '', 'media_list_data': [], 'string_l...
# 1   {'title': '', 'media_list_data': [], 'string_l...
# 2   {'title': '', 'media_list_data': [], 'string_l...
# 3   {'title': '', 'media_list_data': [], 'string_l...
# 4   {'title': '', 'media_list_data': [], 'string_l...
# 5   {'title': '', 'media_list_data': [], 'string_l...
# 6   {'title': '', 'media_list_data': [], 'string_l...
# 7   {'title': '', 'media_list_data': [], 'string_l...
# 8   {'title': '', 'media_list_data': [], 'string_l...
# 9   {'title': '', 'media_list_data': [], 'string_l...
# 10  {'title': '', 'media_list_data': [], 'string_l...
# 11  {'title': '', 'media_list_data': [], 'string_l...>

# %%
dict.keys()
# Out:
# dict_keys(['relationships_following'])

# %%
df_tidy = pd.DataFrame(dict['relationships_following'])

# %%
df_tidy.head()
# Out:
#   title media_list_data                                   string_list_data
# 0                    []  [{'href': 'https://www.instagram.com/lexiscali...
# 1                    []  [{'href': 'https://www.instagram.com/sarahhope...
# 2                    []  [{'href': 'https://www.instagram.com/paigethro...
# 3                    []  [{'href': 'https://www.instagram.com/misspaige...
# 4                    []  [{'href': 'https://www.instagram.com/delaneypa...

# %%
df_tidy['Account'] = [i[0]['value'] for i in df_tidy['string_list_data']]

df_tidy.head()
# Out:
#   title media_list_data                                   string_list_data  \
# 0                    []  [{'href': 'https://www.instagram.com/lexiscali...
# 1                    []  [{'href': 'https://www.instagram.com/sarahhope...
# 2                    []  [{'href': 'https://www.instagram.com/paigethro...
# 3                    []  [{'href': 'https://www.instagram.com/misspaige...
# 4                    []  [{'href': 'https://www.instagram.com/delaneypa...
#
#                Account
# 0          lexiscalise
# 1        sarahhopebeck
# 2      paigethrowsclay
# 3  misspaige.elizabeth
# 4        delaneyparisi

# %%
df_tidy.drop(columns = ['string_list_data'])
df_tidy.drop(columns = ['media_list_data'])
# Out:
#    title                                   string_list_data  \
# 0         [{'href': 'https://www.instagram.com/lexiscali...
# 1         [{'href': 'https://www.instagram.com/sarahhope...
# 2         [{'href': 'https://www.instagram.com/paigethro...
# 3         [{'href': 'https://www.instagram.com/misspaige...
# 4         [{'href': 'https://www.instagram.com/delaneypa...
# 5         [{'href': 'https://www.instagram.com/jocelynma...
# 6         [{'href': 'https://www.instagram.com/julesonbr...
# 7         [{'href': 'https://www.instagram.com/l.mitchhh...
# 8         [{'href': 'https://www.instagram.com/mike.wags...
# 9         [{'href': 'https://www.instagram.com/iam_412',...
# 10        [{'href': 'https://www.instagram.com/usebothof...
# 11        [{'href': 'https://www.instagram.com/epaul5305...
#
#                     Account
# 0               lexiscalise
# 1             sarahhopebeck
# 2           paigethrowsclay
# 3       misspaige.elizabeth
# 4             delaneyparisi
# ...

# %% [markdown]
# ## Section 10 - In a Markdown cell, describe what you think the data in the DataFrame represents, whether the DataFrame meets tidy principles, and whether the data can be used to test your hypothesis.

# %% [markdown]
# The data in the DataFrame represents the accounts that I follow in the far right column. I do believe this meets tidy principles, as unnecessary columns have been removed. This data could easily be used to test my hypothesis.

# %% [markdown]
# By looking at the account names, I can tell that 10 of the 12 listed accounts are people that I personally know, confirming my hypothesis.
